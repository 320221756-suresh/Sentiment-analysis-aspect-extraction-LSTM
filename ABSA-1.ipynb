# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:/Users/JP/Downloads/womens-ecommerce-clothing-reviews/clothing_review.csv",index_col=False)

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df.shape
# Out:
# (23486, 11)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
df.shape
df['Title']=df['Title'].fillna(' ')
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33
# 1           1         1080   34
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df=df.dropna()
df=df.reset_index()

# %%
df.shape
# Out:
# (22628, 12)

# %%
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df['Review']=df['Title']+df['Review Text']

# %%
df.head(2)
# Out:
#    index  Unnamed: 0  Clothing ID  Age Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
#
#    Positive Feedback Count Division Name Department Name Class Name  \
# 0                        0     Initmates        Intimate  Intimates
# 1                        4       General         Dresses    Dresses
#
#                                               Review
# 0   Absolutely wonderful - silky and sexy and com...
# 1   Love this dress!  it's sooo pretty.  i happen...

# %%
import spacy
from tqdm import tqdm
nlp = spacy.load('en_core_web_md', parse=True, tag=True,)

# %%
df['Review'][2]
# Out:
# 'Some major design flawsI had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c'

# %%
txt = "good design and good quality"
doc = nlp(txt)
spacy.displacy.render(doc,style='dep',jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="427655a53e84430785a0c176f1bd5fb2-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">design</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">quality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-427655a53e84430785a0c176f1bd5fb2-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-427655a53e84430785a0c176f1bd5fb2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-427655a53e84430785a0c176f1bd5fb2-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-427655a53e84430785a0c176f1bd5fb2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-427655a53e84430785a0c176f1bd5fb2-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-427655a53e84430785a0c176f1bd5fb2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-427655a53e84430785a0c176f1bd5fb2-0-3" stroke-width="2px" d="M245,177.0 C245,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-427655a53e84430785a0c176f1bd5fb2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg>

# %%
txt = "It was soft and nice"
doc = nlp(txt)
spacy.displacy.render(doc,style='dep',jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1c453839f449412e95126f9080caef0b-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">soft</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">nice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c453839f449412e95126f9080caef0b-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c453839f449412e95126f9080caef0b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c453839f449412e95126f9080caef0b-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c453839f449412e95126f9080caef0b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c453839f449412e95126f9080caef0b-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c453839f449412e95126f9080caef0b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c453839f449412e95126f9080caef0b-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c453839f449412e95126f9080caef0b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg>

# %%
txt = "The clothes are too thin, too sheer, cheaply made, are of overall awful quality and often fall apart"
doc = nlp(txt)
spacy.displacy.render(doc,style='dep',jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4f81722cf5d04924b405085eb94b10ef-0" class="displacy" width="3200" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">clothes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">too</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">thin,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">too</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">sheer,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">cheaply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">made,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">overall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">awful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">quality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">often</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">fall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">apart</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f81722cf5d04924b405085eb94b10ef-0-0" stroke-width="2px" d="M70,527.0 C70,439.5 200.0,439.5 200.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f81722cf5d04924b405085eb94b10ef-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f81722cf5d04924b405085eb94b10ef-0-1" stroke-width="2px" d="M245,527.0 C245,439.5 375.0,439.5 375.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f81722cf5d04924b405085eb94b10ef-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f81722cf5d04924b405085eb94b10ef-0-2" stroke-width="2px" d="M595,527.0 C595,439.5 725.0,439.5 725.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f81722cf5d04924b405085eb94b10ef-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,529.0 L587,517.0 603,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f81722cf5d04924b405085eb94b10ef-0-3" stroke-width="2px" d="M420,527.0 C420,352.0 730.0,352.0 730.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f81722cf5d04924b405085eb94b10ef-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730.0,529.0 L738.0,517.0 722.0,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f81722cf5d04924b405085eb94b10ef-0-4" stroke-width="2px" d="M945,527.0 C945,439.5 1075.0,439.5 1075.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f81722cf5d04924b405085eb94b10ef-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,529.0 L937,517.0 953,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f81722cf5d04924b405085eb94b10ef-0-5" stroke-width="2px" d="M770,527.0 C770,352.0 1080.0,352.0 1080.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f81722cf5d04924b4050

# %%
competitors = ['Flipkart','Ajio','Reliance Trends','Myntra','Koovs.com']

# %%
import re
aspect_terms = []
comp_terms = []
easpect_terms = []
ecomp_terms = []
enemy = []
for x in tqdm(range(len(df['Review']))):
    amod_pairs = []
    advmod_pairs = []
    compound_pairs = []
    xcomp_pairs = []
    neg_pairs = []
    eamod_pairs = []
    eadvmod_pairs = []
    ecompound_pairs = []
    eneg_pairs = []
    excomp_pairs = []
    enemlist = []
    if len(str(df['Review'][x])) != 0:
        lines = str(df['Review'][x]).replace('*',' ').replace('-',' ').replace('so ',' ').replace('be ',' ').replace('are ',' ').replace('just ',' ').replace('get ','').replace('were ',' ').replace('When ','').replace('when ','').replace('again ',' ').replace('where ','').replace('how ',' ').replace('has ',' ').replace('Here ',' ').replace('here ',' ').replace('now ',' ').replace('see ',' ').replace('why ',' ').split('.')       
        
        for line in lines:
                #print(line)
                doc = nlp(line)
                str1=''
                str2=''
                for token in doc:
                    #print(token.pos_)
                    if token.pos_ is 'NOUN':
                        for j in token.lefts:
                            if j.dep_ == 'compound':
                                #print(j.dep_)
                                compound_pairs.append((j.text+' '+token.text,token.text))
                            if j.dep_ is 'amod' and j.pos_ is 'ADJ': #primary condition
                                str1 = j.text+' '+token.text
                                amod_pairs.append(j.text+' '+token.text)
                                for k in j.lefts:
                                    if k.dep_ is 'advmod': #secondary condition to get adjective of adjectives
                                        str2 = k.text+' '+j.text+' '+token.text
                                        amod_pairs.append(k.text+' '+j.text+' '+token.text)
                                mtch = re.search(re.escape(str1),re.escape(str2))
                                if mtch is not None:
                                    amod_pairs.remove(str1)
                    if token.pos_ is 'VERB':
                        for j in token.lefts:
                            if j.dep_ is 'advmod' and j.pos_ is 'ADV':
                                advmod_pairs.append(j.text+' '+token.text)
                            if j.dep_ is 'neg' and j.pos_ is 'ADV':
                                neg_pairs.append(j.text+' '+token.text)
                        for j in token.rights:
                            if j.dep_ is 'advmod'and j.pos_ is 'ADV':
                                advmod_pairs.append(token.text+' '+j.text)
                    if token.pos_ is 'ADJ':
                        for j,h in zip(token.rights,token.lefts):
                            if j.dep_ is 'xcomp' and h.dep_ is not 'neg':
                                for k in j.lefts:
                                    if k.dep_ is 'aux':
                                        xcomp_pairs.append(token.text+' '+k.text+' '+j.text)
                            elif j.dep_ is 'xcomp' and h.dep_ is 'neg':
                                if k.dep_ is 'aux':
                                        neg_pairs.append(h.text +' '+token.text+' '+k.text+' '+j.text)
                       
           
        pairs = list(set(amod_pairs+advmod_pairs+neg_pairs+xcomp_pairs))
        epairs = list(set(eamod_pairs+eadvmod_pairs+eneg_pairs+excomp_pairs))
        for i in range(len(pairs)):
            if len(compound_pairs)!=0:
                for comp in compound_pairs:
                    mtch = re.search(re.escape(comp[1]),re.escape(pairs[i]))
                    if mtch is not None:
                        pairs[i] = pairs[i].replace(mtch.group(),comp[0])
        for i in range(len(epairs)):
            if len(ecompound_pairs)!=0:
                for comp in ecompound_pairs:
                    mtch = re.search(re.escape(comp[1]),re.escape(epairs[i]))
                    if mtch is not None:
                        epairs[i] = epairs[i].replace(mtch.group(),comp[0])
            
    aspect_terms.append(pairs)
    comp_terms.append(compound_pairs)
    easpect_terms.append(epairs)
    ecomp_terms.append(ecompound_pairs)
    enemy.append(enemlist)
df['compound_nouns'] = comp_terms
df['aspect_keywords'] = aspect_terms
df['competition'] = enemy
df['competition_comp_nouns'] = ecomp_terms
df['competition_aspects'] = easpect_terms
df.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 22628/22628 [28:23<00:00, 13.29it/s]
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords competition  \
# 0                                                 []          []
# 1         [never ordered, ordered online, true midi]          []
# 2  [major design, initially ordered, such hopes, ...          []
# 3           [favorite buy!I love, great compliments]          []
# 4  [adjustable front tie, Flattering shirt, perfe...          []
#
#   competition_comp_nouns competition_aspects
# 0                     []                  []
# 1                     []                  []
# 2                     []                  []
# 3                     []                  []
# 4                     []                  []

# %%
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords competition  \
# 0                                                 []          []
# 1         [never ordered, ordered online, true midi]          []
# 2  [major design, initially ordered, such hopes, ...          []
# 3           [favorite buy!I love, great compliments]          []
# 4  [adjustable front tie, Flattering shirt, perfe...          []
#
#   competition_comp_nouns competition_aspects
# 0                     []                  []
# 1                     []                  []
# 2                     []                  []
# 3                     []                  []
# 4                     []                  []

# %%
df['aspect_keywords'].count()
# Out:
# 22628

# %%
df.drop(['competition', 'competition_comp_nouns','competition_aspects'], axis=1,inplace=True)
df
# Out:
#        index  Unnamed: 0  Clothing ID  Age  \
# 0          0           0          767   33
# 1          1           1         1080   34
# 2          2           2         1077   60
# 3          3           3         1049   50
# 4          4           4          847   47
# ...      ...         ...          ...  ...
# 22623  23481       23481         1104   34
# 22624  23482       23482          862   48
# 22625  23483       23483         1104   31
# 22626  23484       23484         1084   28
# 22627  23485       23485         1104   52
#
#                                                    Title  \
# 0
# 1
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 22623                     Great dress for many occasions
# 22624                         Wish it was made of cotton
# 22625                              Cute, but see through
# 22626  Very cute dress, perfect for summer parties an...
# 22627                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 22623  I was very happy to snag this dress at such a ...       5
# 22624  It reminds me of maternity clothes. soft, stre...       3
# 22625  This fit well, but the top was very see throug...       3
# 22626  I bought this dress for a wedding i have this ...       3
# 22627  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    1                        0       Initmates
# 1                    1                        4         General
# 2                    0                        0         General
# 3                    1                        0  General Petite
# 4                    1                        6         General
# ...                ...                      ...             ...
# 22623                1                        0  General Petite
# 22624                1                        0  General Petite
# 22625                0                        1  General Petite
# 22626                1                        2         General
# 22627                1                       22  General Petite
#
#       Department Name Class Name  \
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 22623         Dresses    Dresses
# 22624            Tops      Knits
# 22625         Dresses    Dresses
# 22626         Dresses    Dresses
# 22627         Dresses    Dresses
#
#                                                   Review  \
# 0       Absolutely wonderful - silky and sexy and com...
# 1       Love this dress!  it's sooo pretty.  i happen...
# 2      Some major design flawsI had such high hopes f...
# 3      My favorite buy!I love, love, love this jumpsu...
# 4      Flattering shirtThis shirt is very flattering ...
# ...                                                  ...
# 22623  Great dress for many occasionsI was very happy...
# 22624  Wish it was made of cottonIt reminds me of mat...
# 22625  Cute, but see throughThis fit well, but the to...
# 22626  Very cute dress, perfect for summer parties an...
# 22627  Please make more like this one!This dress in a...
#
#                                           compound_nouns  \
# 0                                                     []
# 1                                                     []
# 2                                  [(design flaw, flaw)]
# 3                                   [(buy!I love, love)]
# 4                                     [(front tie, tie)]
# ...                                                  ...
# 22623                             [(color combo, combo)]
# 22624                     [(maternity clothes, clothes)]
# 22625                                                 []
# 22626  [(summer parties, parties), (side note, note),...
# 22627                          [(one!This dress, dress)]
#
#                                          aspect_keywords
# 0                                                     []
# 1             [never ordered, ordered online, true midi]
# 2      [major design, initially ordered, such hopes, ...
# 3               [favorite buy!I love, great compliments]
# 4      [adjustable front tie, Flattering shirt, perfe...
# ...                                                  ...
# 22623  [great price, easy to slip, Great dress, flatt...
# 22624  [long sleeves, soft material, nice sleeves, on...
# 22625  [different fabric, fit well, never worked, ord...
# 22626  [much cheaper t, cheaper t, cute dress, Very c...
# 22627  [fits perfectly, highly recommend, lovely plat...
#
# [22628 rows x 15 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
import operator
sentiment = []
for i in range(len(df)):
    score_dict={'pos':0,'neg':0,'neu':0}
    if len(df['aspect_keywords'][i])!=0: 
        for aspects in df['aspect_keywords'][i]:
            sent = analyser.polarity_scores(aspects)
            score_dict['neg'] += sent['neg']
            score_dict['pos'] += sent['pos']
        #score_dict['neu'] += sent['neu']
        sentiment.append(max(score_dict.items(), key=operator.itemgetter(1))[0])
    else:
        sentiment.append('NaN')
df['sentiment'] = sentiment
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords sentiment
# 0                                                 []       NaN
# 1         [never ordered, ordered online, true midi]       pos
# 2  [major design, initially ordered, such hopes, ...       pos
# 3           [favorite buy!I love, great compliments]       pos
# 4  [adjustable front tie, Flattering shirt, perfe...       pos

# %%
df['sentiment'].unique()
# Out:
# array(['NaN', 'pos', 'neg'], dtype=object)

# %%
int_sent = []
for sent in df['sentiment']:
    if sent is 'NaN':
        int_sent.append('NaN')
    elif sent is 'pos':
        int_sent.append('1')
    else:
        int_sent.append('0')
df['int_sent'] = int_sent
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords sentiment int_sent
# 0                                                 []       NaN      NaN
# 1         [never ordered, ordered online, true midi]       pos        1
# 2  [major design, initially ordered, such hopes, ...       pos        1
# 3           [favorite buy!I love, great compliments]       pos        1
# 4  [adjustable front tie, Flattering shirt, perfe...       pos        1

# %%
import math
pos = []
for i in range(len(df)):
    if not math.isnan(df['Rating'][i]):
        if int(df['Rating'][i])>3:
            pos.append('1')
        else:
            pos.append('0')
    else:
        pos.append('0')
df['Positive Review'] = pos
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords sentiment int_sent  \
# 0                                                 []       NaN      NaN
# 1         [never ordered, ordered online, true midi]       pos        1
# 2  [major design, initially ordered, such hopes, ...       pos        1
# 3           [favorite buy!I love, great compliments]       pos        1
# 4  [adjustable front tie, Flattering shirt, perfe...       pos        1
#
#   Positive Review
# 0               1
# 1               1
# 2               0
# 3               1
# 4               1

# %%
d = {'sent':df['Positive Review'],'sent_pred':df['int_sent']}
metric_df = pd.DataFrame(data=d)
metric_df.head()
# Out:
#   sent sent_pred
# 0    1       NaN
# 1    1         1
# 2    0         1
# 3    1         1
# 4    1         1

# %%
len(metric_df.sent)
# Out:
# 22628

# %%
metric_df = metric_df[metric_df.sent_pred != 'NaN']
len(metric_df.sent)
# Out:
# 21503

# %%
from sklearn.metrics import accuracy_score,auc,f1_score,recall_score,precision_score
print('accuracy')
print(accuracy_score(metric_df.sent, metric_df.sent_pred))
print('f1 score')
print(f1_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
print('recall')
print(recall_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
print('precision')
print(precision_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
# Out:
# accuracy
# 0.7734734688183045
# f1 score
# 0.8664711203706242
# recall
# 0.9524498282408245
# precision
# 0.7947299607764257

# %%
import operator
sentiment = []
for i in range(len(df)):
    score_dict={'pos':0,'neg':0,'neu':0}
    if len(df['Review'][i])!=0: 
        for aspects in df['Review'][i]:
            sent = analyser.polarity_scores(aspects)
            score_dict['neg'] += sent['neg']
            score_dict['pos'] += sent['pos']
        
        sentiment.append(max(score_dict.items(), key=operator.itemgetter(1))[0])
    else:
        sentiment.append('NaN')
df['sentiment_review'] = sentiment
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords sentiment int_sent  \
# 0                                                 []       NaN      NaN
# 1         [never ordered, ordered online, true midi]       pos        1
# 2  [major design, initially ordered, such hopes, ...       pos        1
# 3           [favorite buy!I love, great compliments]       pos        1
# 4  [adjustable front tie, Flattering shirt, perfe...       pos        1
#
#   Positive Review sentiment_review
# 0               1              pos
# 1               1              pos
# 2               0              pos
# 3               1              pos
# 4               1              pos

# %%
for i in range(len(df)):
    if df['sentiment'][i]=='NaN':
        df['sentiment'][i]=df['sentiment_review'][i]
# Out:
# C:\Users\JP\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#    index  Unnamed: 0  Clothing ID  Age                    Title  \
# 0      0           0          767   33
# 1      1           1         1080   34
# 2      2           2         1077   60  Some major design flaws
# 3      3           3         1049   50         My favorite buy!
# 4      4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses
#
#                                               Review         compound_nouns  \
# 0   Absolutely wonderful - silky and sexy and com...                     []
# 1   Love this dress!  it's sooo pretty.  i happen...                     []
# 2  Some major design flawsI had such high hopes f...  [(design flaw, flaw)]
# 3  My favorite buy!I love, love, love this jumpsu...   [(buy!I love, love)]
# 4  Flattering shirtThis shirt is very flattering ...     [(front tie, tie)]
#
#                                      aspect_keywords sentiment int_sent  \
# 0                                                 []       pos      NaN
# 1         [never ordered, ordered online, true midi]       pos        1
# 2  [major design, initially ordered, such hopes, ...       pos        1
# 3           [favorite buy!I love, great compliments]       pos        1
# 4  [adjustable front tie, Flattering shirt, perfe...       pos        1
#
#   Positive Review sentiment_review
# 0               1              pos
# 1               1              pos
# 2               0              pos
# 3               1              pos
# 4               1              pos

# %%
df['sentiment'].unique()
# Out:
# array(['pos', 'neg'], dtype=object)

# %%
df.to_csv('F:/AMRITA MTECH/Datascience for NLP/absa.csv')

# %%
df_new=df.filter(['Clothing ID','Age','Rating','Review','Division Name','aspect_keywords','sentiment'], axis=1)

# %%
df_new.head()
# Out:
#    Clothing ID  Age  Rating  \
# 0          767   33       4
# 1         1080   34       5
# 2         1077   60       3
# 3         1049   50       5
# 4          847   47       5
#
#                                               Review   Division Name  \
# 0   Absolutely wonderful - silky and sexy and com...       Initmates
# 1   Love this dress!  it's sooo pretty.  i happen...         General
# 2  Some major design flawsI had such high hopes f...         General
# 3  My favorite buy!I love, love, love this jumpsu...  General Petite
# 4  Flattering shirtThis shirt is very flattering ...         General
#
#                                      aspect_keywords sentiment
# 0                                                 []       pos
# 1         [never ordered, ordered online, true midi]       pos
# 2  [major design, initially ordered, such hopes, ...       pos
# 3           [favorite buy!I love, great compliments]       pos
# 4  [adjustable front tie, Flattering shirt, perfe...       pos

# %%
df_new.shape
# Out:
# (22628, 7)

# %%
n=(df[df['sentiment']=='neg'])

# %%
n.shape
# Out:
# (1617, 19)

# %%
p=(df[df['sentiment']=='pos'])

# %%
p.shape
# Out:
# (21011, 19)

# %%
count=[1606,21022]

# %%
df['sentiment_review'].unique()
# Out:
# array(['pos'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(df.sentiment)
plt.title('Overall sentiment over the product')
# Out:
# Text(0.5,1,'Overall sentiment over the product')

# %%
df_new.to_csv('F:/AMRITA MTECH/Datascience for NLP/absa_refined_latest.csv')

# %%
df
# Out:
#        index  Unnamed: 0  Clothing ID  Age  \
# 0          0           0          767   33
# 1          1           1         1080   34
# 2          2           2         1077   60
# 3          3           3         1049   50
# 4          4           4          847   47
# ...      ...         ...          ...  ...
# 22623  23481       23481         1104   34
# 22624  23482       23482          862   48
# 22625  23483       23483         1104   31
# 22626  23484       23484         1084   28
# 22627  23485       23485         1104   52
#
#                                                    Title  \
# 0
# 1
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 22623                     Great dress for many occasions
# 22624                         Wish it was made of cotton
# 22625                              Cute, but see through
# 22626  Very cute dress, perfect for summer parties an...
# 22627                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 22623  I was very happy to snag this dress at such a ...       5
# 22624  It reminds me of maternity clothes. soft, stre...       3
# 22625  This fit well, but the top was very see throug...       3
# 22626  I bought this dress for a wedding i have this ...       3
# 22627  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    1                        0       Initmates
# 1                    1                        4         General
# 2                    0                        0         General
# 3                    1                        0  General Petite
# 4                    1                        6         General
# ...                ...                      ...             ...
# 22623                1                        0  General Petite
# 22624                1                        0  General Petite
# 22625                0                        1  General Petite
# 22626                1                        2         General
# 22627                1                       22  General Petite
#
#       Department Name Class Name  \
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 22623         Dresses    Dresses
# 22624            Tops      Knits
# 22625         Dresses    Dresses
# 22626         Dresses    Dresses
# 22627         Dresses    Dresses
#
#                                                   Review  \
# 0       Absolutely wonderful - silky and sexy and com...
# 1       Love this dress!  it's sooo pretty.  i happen...
# 2      Some major design flawsI had such high hopes f...
# 3      My favorite buy!I love, love, love this jumpsu...
# 4      Flattering shirtThis shirt is very flattering ...
# ...                                                  ...
# 22623  Great dress for many occasionsI was very happy...
# 22624  Wish it was made of cottonIt reminds me of mat...
# 22625  Cute, but see throughThis fit well, but the to...
# 22626  Very cute dress, perfect for summer parties an...
# 22627  Please make more like this one!This dress in a...
#
#                                           compound_nouns  \
# 0                                                     []
# 1                                                     []
# 2                                  [(design flaw, flaw)]
# 3                                   [(buy!I love, love)]
# 4                                     [(front tie, tie)]
# ...                                                  ...
# 22623                             [(color combo, combo)]
# 22624                     [(maternity clothes, clothes)]
# 22625                                                 []
# 22626  [(summer parties, parties), (side note, note),...
# 22627                          [(one!This dress, dress)]
#
#                                          aspect_keywords sentiment int_sent  \
# 0                                                     []       pos      NaN
# 1             [never ordered, ordered online, true midi]       pos        1
# 2      [major design, initially ordered, such hopes, ...       pos        1
# 3               [favorite buy!I love, great compliments]       pos        1
# 4      [adjustable front tie, Flattering shirt, perfe...       pos        1
# ...                                                  ...       ...      ...
# 22623  [great price, easy to slip, Great dress, flatt...       pos        1
# 22624  [long sleeves, soft material, nice sleeves, on...       pos        1
# 22625  [different fabric, fit well, never worked, ord...       pos        1
# 22626  [much cheaper t, cheaper t, cute dress, Very c...       pos        1
# 22627  [fits perfectly, highly recommend, lovely plat...       pos        1
#
#       Positive Review sentiment_review
# 0                   1              pos
# 1                   1              pos
# 2                   0              pos
# 3                   1              pos
# 4                   1              pos
# ...               ...              ...
# 22623               1              pos
# 22624               0              pos
# 22625               0              pos
# 22626               0              pos
# 22627               1              pos
#
# [22628 rows x 19 columns]

# %%
df_new.shape
# Out:
# (22628, 7)

# %%
df.shape
# Out:
# (22628, 19)

# %%
df_new['Department Name']=df['Department Name']

# %%
df_new['Class Name']=df['Class Name']

# %%
df_new.shape
# Out:
# (22628, 9)

# %%
df_new.head()
# Out:
#    Clothing ID  Age  Rating  \
# 0          767   33       4
# 1         1080   34       5
# 2         1077   60       3
# 3         1049   50       5
# 4          847   47       5
#
#                                               Review   Division Name  \
# 0   Absolutely wonderful - silky and sexy and com...       Initmates
# 1   Love this dress!  it's sooo pretty.  i happen...         General
# 2  Some major design flawsI had such high hopes f...         General
# 3  My favorite buy!I love, love, love this jumpsu...  General Petite
# 4  Flattering shirtThis shirt is very flattering ...         General
#
#                                      aspect_keywords sentiment  \
# 0                                                 []       pos
# 1         [never ordered, ordered online, true midi]       pos
# 2  [major design, initially ordered, such hopes, ...       pos
# 3           [favorite buy!I love, great compliments]       pos
# 4  [adjustable front tie, Flattering shirt, perfe...       pos
#
#   Department Name Class Name
# 0        Intimate  Intimates
# 1         Dresses    Dresses
# 2         Dresses    Dresses
# 3         Bottoms      Pants
# 4            Tops    Blouses

# %%
df['Age'].median()
# Out:
# 41.0

# %%
df['Class Name']
# Out:
# 0        Intimates
# 1          Dresses
# 2          Dresses
# 3            Pants
# 4          Blouses
#            ...
# 22623      Dresses
# 22624        Knits
# 22625      Dresses
# 22626      Dresses
# 22627      Dresses
# Name: Class Name, Length: 22628, dtype: object
